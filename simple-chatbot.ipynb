# %%
# !pip -q install transformers

# %%
from transformers import pipeline
chatbot = pipeline("text2text-generation" , model = "facebook/blenderbot-400M-distill")

# %%
while True:
    user_message = input("Ask questions: ")
    
    if user_message.lower() in ['exit', 'quit']:
        break
    
    response = chatbot(user_message)
    
    print(response)

# %% [markdown]
# ## Asking Follow-up Questions using Conversation

# %%
# !pip -q install transformers
# !pip -q install torch

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.52.4

# %%
from transformers import pipeline

# Load the model
chatbot = pipeline("text2text-generation", model="facebook/blenderbot-400M-distill")

conversation_history = []

while True:
    user_message = input("Ask questions: ")

    if user_message.lower() in ['exit', 'quit']:
        break

    response = chatbot(user_message,)[0]['generated_text']

    print(response)

    conversation_history.append({
        'user': user_message,
        'bot': response
    })
# Out:
# 2025-08-08 16:13:50.302250: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754669630.596121      87 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754669630.682482      87 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/730M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/730M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Ask questions:  Hi
#  Hello, how are you today? I'm doing well, how about you?
# Ask questions:  i am good
#  I am glad to hear that. What do you do for a living? I am a teacher.
# Ask questions:  who is the prime minister of india
#  I'm not sure, but I do know that she is the head of state of India.
# Ask questions:  name?
#  I'm not sure yet, but I'm sure it will come to me when I see it.
# Ask questions:  usa ?
#  I am from the United States, the country that is located in the southeastern region of the world.
# Ask questions:  who is the president of it?
#  I'm not sure, but I know that it's going to be a big deal.
# Ask questions:  what is AI
#  Automotive technologies. It's a field of science that involves the use of technology to solve problems.
# Ask questions:  exit
